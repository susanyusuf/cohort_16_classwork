# %%
import numpy as np

# %%
nums = np.array([1, 3, 5, 7, 9])

# %%
print(nums)
# Out:
# [1 3 5 7 9]

# %%
nums2 =np.array(nums + 2)

# %%
print(nums2)
# Out:
# [ 3  5  7  9 11]

# %%
nums3 = np.array(nums2 * 3)

# %%
print(nums3)
# Out:
# [ 9 15 21 27 33]

# %%
total = np.sum(nums)
Maximum = np.max(nums)
Average = np.mean(nums)
print('Sum:', total)
print('MAximum VAlue:',Maximum)
print('Average:', Average)
# Out:
# Sum: 25
# MAximum VAlue: 9
# Average: 5.0
