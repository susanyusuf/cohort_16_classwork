# %%
import numpy as np

# %%
nums = np.array([1,3,5,7,9])
print (nums)
# Out:
# [1 3 5 7 9]

# %%
nums_plus_2=nums +2
print (nums_plus_2)
# Out:
# [ 3  5  7  9 11]

# %%
nums_times_3=nums * 3
print (nums_times_3)
# Out:
# [ 3  9 15 21 27]

# %%
print(np.sum(nums))
print(np.max(nums))
print(np.mean(nums))
# Out:
# 25
# 9
# 5.0
